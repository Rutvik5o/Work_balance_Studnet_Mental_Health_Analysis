# %%
import pandas as pd
df = pd.read_csv(r"E:\AIDTM\Project\sd1.csv")
import numpy as np

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
print(df.dtypes)
df1=df.copy()
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                          object
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
# df['Financial Stress'] = df['Financial Stress'].astype(int)
# df['Work/Study Hours'] = df['Work/Study Hours'].astype(int)
# df['Depression'] = df['Depression'].astype(int)

df.head(10)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
# 5  33    Male  29.0           Pune    Student                2.0
# 6  52    Male  30.0          Thane    Student                3.0
# 7  56  Female  30.0        Chennai    Student                2.0
# 8  59    Male  28.0         Nagpur    Student                3.0
# 9  62    Male  31.0         Nashik    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# ...

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
#to_numeric-> column to numeric type
#errors : conerce-> value can't convert into num , so its do NaN(missing value) raise,ignore 
df
#convert to number, make invalid value to nan
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
print(df.dropna(inplace=True))
# Out:
# None

# %%
sleep_map = {
    "'Less than 5 hours'": 4,
    "'5-6 hours'": 5.5,
    "'7-8 hours'": 7.5,
    "'More than 8 hours'": 9
}
df['Sleep Duration'] = df['Sleep Duration'].map(sleep_map)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df['Age'] = df['Age'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  int32
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
print(df)
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                5.0
# 1           8  Female   24      Bangalore    Student                2.0
# 2          26    Male   31       Srinagar    Student                3.0
# 3          30  Female   28       Varanasi    Student                3.0
# 4          32  Female   25         Jaipur    Student                4.0
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                5.0
# 27897  140686    Male   27       Ludhiana    Student                2.0
# 27898  140689    Male   31      Faridabad    Student                3.0
# 27899  140690  Female   18       Ludhiana    Student                5.0
# 27900  140699    Male   27          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
print("checking unqiue val wp->",df['Work Pressure'].unique())
print("checking unqiue val on js->", df['Job Satisfaction'].unique())

print("check all val are 0- WP>", (df['Work Pressure'] == 0).all())
print("check all var are 0 JS", (df['Job Satisfaction'] == 0).all())

print("how many 0 value on WP->", (df['Work Pressure'] == 0).sum())
print("how many 0 values on JS->", (df['Job Satisfaction'] == 0).sum())

print("Total dp->", len(df))
# Out:
# checking unqiue val wp-> [0 5 2]
# checking unqiue val on js-> [0. 3. 4. 2. 1.]
# check all val are 0- WP> False
# check all var are 0 JS False
# how many 0 value on WP-> 27860
# how many 0 values on JS-> 27855
# Total dp-> 27863

# %%
#fixinig indexing
df['new_id'] = range(1, len(df) + 1)
print(df)
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                5.0
# 1           8  Female   24      Bangalore    Student                2.0
# 2          26    Male   31       Srinagar    Student                3.0
# 3          30  Female   28       Varanasi    Student                3.0
# 4          32  Female   25         Jaipur    Student                4.0
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                5.0
# 27897  140686    Male   27       Ludhiana    Student                2.0
# 27898  140689    Male   31      Faridabad    Student                3.0
# 27899  140690  Female   18       Ludhiana    Student                5.0
# 27900  140699    Male   27          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.head(10)
# Out:
#    id  Gender  Age           City Profession  Academic Pressure  \
# 0   2    Male   33  Visakhapatnam    Student                5.0
# 1   8  Female   24      Bangalore    Student                2.0
# 2  26    Male   31       Srinagar    Student                3.0
# 3  30  Female   28       Varanasi    Student                3.0
# 4  32  Female   25         Jaipur    Student                4.0
# 5  33    Male   29           Pune    Student                2.0
# 6  52    Male   30          Thane    Student                3.0
# 7  56  Female   30        Chennai    Student                2.0
# 8  59    Male   28         Nagpur    Student                3.0
# 9  62    Male   31         Nashik    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0             5.5
# 1            0.0  5.90                 5.0               0.0             5.5
# ...

# %%
cols = list(df.columns)
#coverting df to regular python for manipulate

id_index = cols.index('id')
#getting index of id column 

cols.insert(id_index + 1, cols.pop(cols.index('new_id'))) 
#col pop -> getting index of current new-id  post and delete it
#and insert at after id column

df = df[cols]
#reassigning the df with new column order
df.head(10)
# Out:
#    id  new_id  Gender  Age           City Profession  Academic Pressure  \
# 0   2       1    Male   33  Visakhapatnam    Student                5.0
# 1   8       2  Female   24      Bangalore    Student                2.0
# 2  26       3    Male   31       Srinagar    Student                3.0
# 3  30       4  Female   28       Varanasi    Student                3.0
# 4  32       5  Female   25         Jaipur    Student                4.0
# 5  33       6    Male   29           Pune    Student                2.0
# 6  52       7    Male   30          Thane    Student                3.0
# 7  56       8  Female   30        Chennai    Student                2.0
# 8  59       9    Male   28         Nagpur    Student                3.0
# 9  62      10    Male   31         Nashik    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0             5.5
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   new_id                                 27901 non-null  int64
#  2   Gender                                 27901 non-null  object
#  3   Age                                    27901 non-null  int32
#  4   City                                   27901 non-null  object
#  5   Profession                             27901 non-null  object
#  6   Academic Pressure                      27901 non-null  float64
#  7   Work Pressure                          27901 non-null  float64
#  8   CGPA                                   27901 non-null  float64
#  9   Study Satisfaction                     27901 non-null  float64
# ...

# %%
# df['Financial Stress'] = df['Financial Stress'].astype(float)
# df.info()
print("check all val are 0->", (df['Financial Stress'] == "0").all()
)
#knowing all value are 0 or not (through all) 


#we knowing our column in "?" value
for i in range (0,27901):
    if df["Financial Stress"][i] == "?":
        print("there ? is on->",i+1)
# Out:
# check all val are 0-> False
# there ? is on-> 4459
# there ? is on-> 13597
# there ? is on-> 19267

# %%
df.columns
# Out:
# Index(['id', 'new_id', 'Gender', 'Age', 'City', 'Profession',
#        'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction',
#        'Job Satisfaction', 'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
for i in df.columns:
    print(f"column->{i}",df[i].unique())
# Out:
# column->id [     2      8     26 ... 140689 140690 140699]
# column->new_id [    1     2     3 ... 27899 27900 27901]
# column->Gender ['Male' 'Female']
# column->Age [33 24 31 28 25 29 30 27 19 20 23 18 21 22 34 32 26 39 35 42 36 58 49 38
#  51 44 43 46 59 54 48 56 37 41]
# column->City ['Visakhapatnam' 'Bangalore' 'Srinagar' 'Varanasi' 'Jaipur' 'Pune' 'Thane'
#  'Chennai' 'Nagpur' 'Nashik' 'Vadodara' 'Kalyan' 'Rajkot' 'Ahmedabad'
#  'Kolkata' 'Mumbai' 'Lucknow' 'Indore' 'Surat' 'Ludhiana' 'Bhopal'
#  'Meerut' 'Agra' 'Ghaziabad' 'Hyderabad' 'Vasai-Virar' 'Kanpur' 'Patna'
#  'Faridabad' 'Delhi' 'Saanvi' 'M.Tech' 'Bhavna' "'Less Delhi'" 'City'
#  '3.0' "'Less than 5 Kalyan'" 'Mira' 'Harsha' 'Vaanya' 'Gaurav' 'Harsh'
#  'Reyansh' 'Kibara' 'Rashi' 'ME' 'M.Com' 'Nalyan' 'Mihir' 'Nalini'
#  'Nandini' 'Khaziabad']
# column->Profession ['Student' "'Civil Engineer'" 'Architect' "'UX/UI Designer'"
#  "'Digital Marketer'" "'Content Writer'" "'Educational Consultant'"
# ...

# %%
# for i in range (0,27901):
#     if df["Financial Stress"][i] == "?":
#          df["Financial Stress"][i].fillna(df["Age"].mean())

df["Financial Stress"] = df["Financial Stress"].replace("?", np.nan)
#replacing ? to np.an make to regonizable as missing value

df["Financial Stress"].unique()
#actual value showa sunique 

###for financial stress
# Convert column to numeric
df["Financial Stress"] = pd.to_numeric(df["Financial Stress"], errors='coerce') #some non convertial so it also do
#convert column to numericc, if any non-numeric value reamin convert to NaN.

# Fill NaN with mean
df["Financial Stress"].fillna(df["Financial Stress"].mean(), inplace=True)
#replace all Nan value to column mean value


###for sleep duration
# df["Sleep Duration"] = pd.to_numeric(df["Sleep Duration"] , errors='coerce')

# # Fill NaN with mean
# df["Sleep Duration"].fillna(df["Sleep Duration"] .mean(), inplace=True)

# # Check
# print(df["Financial Stress"].unique())

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   new_id                                 27901 non-null  int64
#  2   Gender                                 27901 non-null  object
#  3   Age                                    27901 non-null  int32
#  4   City                                   27901 non-null  object
#  5   Profession                             27901 non-null  object
#  6   Academic Pressure                      27901 non-null  float64
#  7   Work Pressure                          27901 non-null  float64
#  8   CGPA                                   27901 non-null  float64
#  9   Study Satisfaction                     27901 non-null  float64
# ...

# %%
for i in df.columns:
    print(f"column->{i}",df[i].unique())
# Out:
# column->id [     2      8     26 ... 140689 140690 140699]
# column->new_id [    1     2     3 ... 27899 27900 27901]
# column->Gender ['Male' 'Female']
# column->Age [33 24 31 28 25 29 30 27 19 20 23 18 21 22 34 32 26 39 35 42 36 58 49 38
#  51 44 43 46 59 54 48 56 37 41]
# column->City ['Visakhapatnam' 'Bangalore' 'Srinagar' 'Varanasi' 'Jaipur' 'Pune' 'Thane'
#  'Chennai' 'Nagpur' 'Nashik' 'Vadodara' 'Kalyan' 'Rajkot' 'Ahmedabad'
#  'Kolkata' 'Mumbai' 'Lucknow' 'Indore' 'Surat' 'Ludhiana' 'Bhopal'
#  'Meerut' 'Agra' 'Ghaziabad' 'Hyderabad' 'Vasai-Virar' 'Kanpur' 'Patna'
#  'Faridabad' 'Delhi' 'Saanvi' 'M.Tech' 'Bhavna' "'Less Delhi'" 'City'
#  '3.0' "'Less than 5 Kalyan'" 'Mira' 'Harsha' 'Vaanya' 'Gaurav' 'Harsh'
#  'Reyansh' 'Kibara' 'Rashi' 'ME' 'M.Com' 'Nalyan' 'Mihir' 'Nalini'
#  'Nandini' 'Khaziabad']
# column->Profession ['Student' "'Civil Engineer'" 'Architect' "'UX/UI Designer'"
#  "'Digital Marketer'" "'Content Writer'" "'Educational Consultant'"
# ...

# %%
df['Financial Stress'] = df['Financial Stress'].astype(int)
# df['Sleep Duration'] = df['Sleep Duration'].astype(int)

print(df['Financial Stress'].unique())

print(df.head(5))
# print(df['Sleep Duration'].unique())
# Out:
# [1 2 5 3 4]
#    id  new_id  Gender  Age           City Profession  Academic Pressure  \
# 0   2       1    Male   33  Visakhapatnam    Student                5.0
# 1   8       2  Female   24      Bangalore    Student                2.0
# 2  26       3    Male   31       Srinagar    Student                3.0
# 3  30       4  Female   28       Varanasi    Student                3.0
# 4  32       5  Female   25         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0             5.5
# 1            0.0  5.90                 5.0               0.0             5.5
# 2            0.0  7.03                 5.0               0.0             4.0
# 3            0.0  5.59                 2.0               0.0             7.5
# 4            0.0  8.13                 3.0               0.0             5.5
#
# ...

# %%
## make city strcture wise

# %%
print(df['City'])
# Out:
# 0        Visakhapatnam
# 1            Bangalore
# 2             Srinagar
# 3             Varanasi
# 4               Jaipur
#              ...
# 27896            Surat
# 27897         Ludhiana
# 27898        Faridabad
# 27899         Ludhiana
# 27900            Patna
# Name: City, Length: 27901, dtype: object

# %%
miscellous = {
    "'Less than 5 Kalyan'": "Kalyan",
    "'Less Delhi'": "Delhi"
}
#key-> incorrect citiy names, value-> correct

df['City'] = df['City'].replace(miscellous)
#repacling inot that

print(df['City'].unique())
# Out:
# ['Visakhapatnam' 'Bangalore' 'Srinagar' 'Varanasi' 'Jaipur' 'Pune' 'Thane'
#  'Chennai' 'Nagpur' 'Nashik' 'Vadodara' 'Kalyan' 'Rajkot' 'Ahmedabad'
#  'Kolkata' 'Mumbai' 'Lucknow' 'Indore' 'Surat' 'Ludhiana' 'Bhopal'
#  'Meerut' 'Agra' 'Ghaziabad' 'Hyderabad' 'Vasai-Virar' 'Kanpur' 'Patna'
#  'Faridabad' 'Delhi' 'Saanvi' 'M.Tech' 'Bhavna' 'City' '3.0' 'Mira'
#  'Harsha' 'Vaanya' 'Gaurav' 'Harsh' 'Reyansh' 'Kibara' 'Rashi' 'ME'
#  'M.Com' 'Nalyan' 'Mihir' 'Nalini' 'Nandini' 'Khaziabad']

# %%
## Removing this cities which is not valid=> "3.0","Gaurav","Harsh",'Harsha","M.Com","Mihir","ME",

##making copy of that original

# %%
df2=df.copy()
print("DF2 is data where we not perfrom city clearning-")
# Out:
# DF2 is data where we not perfrom city clearning-

# %%
wrong_cities = ["M.Tech", "City","3","3.0","Mira","Harsha","Gaurav","Harsh","Reyansh","Rashi","ME","M.Com","Mihir","Nalini","Nandini","Saanvi","Bhavna"]


#=>dropping rows where City matches any of these
df = df[~df['City'].isin(wrong_cities)]
#df['City'].isin(wrong_cities) -> true for row where city in wrong cities
#~-> flip to true to false , false to true
#df to keep oly row where condition is true


#keeping only row where city is not in wrong ciites

# %%
df = df.dropna(subset=['id', 'new_id', 'Gender', 'Age', 'City', 'Profession',
       'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction',
       'Job Satisfaction', 'Sleep Duration', 'Dietary Habits', 'Degree',
       'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
       'Financial Stress', 'Family History of Mental Illness', 'Depression'])

#dropna()-> remove rows with missing value -> NaN
#subset-> for columns
#-> if any one of these columns has a misssingvalue in row so that dopped

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27863 entries, 0 to 27900
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27863 non-null  int64
#  1   new_id                                 27863 non-null  int64
#  2   Gender                                 27863 non-null  object
#  3   Age                                    27863 non-null  int32
#  4   City                                   27863 non-null  object
#  5   Profession                             27863 non-null  object
#  6   Academic Pressure                      27863 non-null  float64
#  7   Work Pressure                          27863 non-null  float64
#  8   CGPA                                   27863 non-null  float64
#  9   Study Satisfaction                     27863 non-null  float64
# ...

# %%
df['id'] = df['id'].astype(int)
df['new_id'] = df['new_id'].astype(int)
df['Age'] = df['Age'].astype(int)
df['Depression'] = df['Depression'].astype(int)

# %%
for i in df.columns:
    print(f"column->{i}",df[i].unique())
# Out:
# column->id [     2      8     26 ... 140689 140690 140699]
# column->new_id [    1     2     3 ... 27899 27900 27901]
# column->Gender ['Male' 'Female']
# column->Age [33 24 31 28 25 29 30 27 19 20 23 18 21 22 34 32 26 39 35 42 36 58 49 38
#  51 44 43 46 59 54 48 56 37 41]
# column->City ['Visakhapatnam' 'Bangalore' 'Srinagar' 'Varanasi' 'Jaipur' 'Pune' 'Thane'
#  'Chennai' 'Nagpur' 'Nashik' 'Vadodara' 'Kalyan' 'Rajkot' 'Ahmedabad'
#  'Kolkata' 'Mumbai' 'Lucknow' 'Indore' 'Surat' 'Ludhiana' 'Bhopal'
#  'Meerut' 'Agra' 'Ghaziabad' 'Hyderabad' 'Vasai-Virar' 'Kanpur' 'Patna'
#  'Faridabad' 'Delhi' 'Vaanya' 'Kibara' 'Nalyan' 'Khaziabad']
# column->Profession ['Student' "'Civil Engineer'" 'Architect' "'UX/UI Designer'"
#  "'Digital Marketer'" "'Content Writer'" "'Educational Consultant'"
#  'Teacher' 'Manager' 'Chef' 'Doctor' 'Lawyer' 'Entrepreneur' 'Pharmacist']
# column->Academic Pressure [5. 2. 3. 4. 1. 0.]
# column->Work Pressure [0. 5. 2.]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27863 entries, 0 to 27900
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27863 non-null  int32
#  1   new_id                                 27863 non-null  int32
#  2   Gender                                 27863 non-null  object
#  3   Age                                    27863 non-null  int32
#  4   City                                   27863 non-null  object
#  5   Profession                             27863 non-null  object
#  6   Academic Pressure                      27863 non-null  float64
#  7   Work Pressure                          27863 non-null  float64
#  8   CGPA                                   27863 non-null  float64
#  9   Study Satisfaction                     27863 non-null  float64
# ...

# %%
df['Financial Stress'] = df['Financial Stress'].astype(int)
df['Work/Study Hours'] = df['Work/Study Hours'].astype(int)
df['Academic Pressure'] = df['Academic Pressure'].astype(int)
df['Work Pressure'] = df['Work Pressure'].astype(int)
df['Study Satisfaction'] = df['Study Satisfaction'].astype(int)
df['Job Satisfactionn'] = df['Job Satisfaction'].astype(int)

# %%
df['Degree'] = df2['Degree'] #mistakly erased all valyue of degree so solved that
df.head(10)
# Out:
#    id  new_id  Gender  Age           City Profession  Academic Pressure  \
# 0   2       1    Male   33  Visakhapatnam    Student                  5
# 1   8       2  Female   24      Bangalore    Student                  2
# 2  26       3    Male   31       Srinagar    Student                  3
# 3  30       4  Female   28       Varanasi    Student                  3
# 4  32       5  Female   25         Jaipur    Student                  4
# 5  33       6    Male   29           Pune    Student                  2
# 6  52       7    Male   30          Thane    Student                  3
# 7  56       8  Female   30        Chennai    Student                  2
# 8  59       9    Male   28         Nagpur    Student                  3
# 9  62      10    Male   31         Nashik    Student                  2
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0              0  8.97                   2               0.0             5.5
# ...

# %%
df['Degree'] = df['Degree'].str.replace("'", "", regex=False) #removing all single quote values
#str.replcae9) -> appluing string replacement ot each in value in degree column
#regerx false -> tresat the pattern as literal char, noht a regular expression
df.head(10)
# Out:
#    id  new_id  Gender  Age           City Profession  Academic Pressure  \
# 0   2       1    Male   33  Visakhapatnam    Student                  5
# 1   8       2  Female   24      Bangalore    Student                  2
# 2  26       3    Male   31       Srinagar    Student                  3
# 3  30       4  Female   28       Varanasi    Student                  3
# 4  32       5  Female   25         Jaipur    Student                  4
# 5  33       6    Male   29           Pune    Student                  2
# 6  52       7    Male   30          Thane    Student                  3
# 7  56       8  Female   30        Chennai    Student                  2
# 8  59       9    Male   28         Nagpur    Student                  3
# 9  62      10    Male   31         Nashik    Student                  2
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0              0  8.97                   2               0.0             5.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27863 entries, 0 to 27900
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27863 non-null  int32
#  1   new_id                                 27863 non-null  int32
#  2   Gender                                 27863 non-null  object
#  3   Age                                    27863 non-null  int32
#  4   City                                   27863 non-null  object
#  5   Profession                             27863 non-null  object
#  6   Academic Pressure                      27863 non-null  int32
#  7   Work Pressure                          27863 non-null  int32
#  8   CGPA                                   27863 non-null  float64
#  9   Study Satisfaction                     27863 non-null  int32
# ...

# %%
df.to_csv("cs2.csv",index=False)
